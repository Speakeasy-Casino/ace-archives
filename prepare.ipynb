# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
import requests
import acquire as a
import re
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize.toktok import ToktokTokenizer
import requests
import unicodedata
import nltk
from textblob import TextBlob, Word
from nltk.stem import PorterStemmer, SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('links.csv').drop(columns = 'Unnamed: 0')
df['href'] = df['href'].str[1:]
df.to_csv('links2.csv', index = False)
df
# Out:
#                                                   href
# 0       learn-co-students/simple-blackjack-cli-prework
# 1                       rocketacademy/basics-blackjack
# 2                                     datamllab/rlcard
# 3    learn-co-students/simple-blackjack-cli-001-pre...
# 4          cocos-creator/tutorial-blackjack-deprecated
# ..                                                 ...
# 435                    TigerZen/Unity3D-BlackJack-Dapp
# 436   merdoyovski/Modified-Blackjack_Reach-Bounty-Hack
# 437                          DEEBAZZ890/Blackjack-game
# 438                             cs361-W16/Blackjack-14
# 439                              cs361-W16/Blackjack-8
#
# [440 rows x 1 columns]

# %%
df2 = a.get_dataframe(df.href)
df2
# Out:
#                                                   repo    language  \
# 0       learn-co-students/simple-blackjack-cli-prework        Ruby
# 1                       rocketacademy/basics-blackjack        HTML
# 2                                     datamllab/rlcard      Python
# 3    learn-co-students/simple-blackjack-cli-001-pre...        Ruby
# 4          cocos-creator/tutorial-blackjack-deprecated  JavaScript
# ..                                                 ...         ...
# 435                    TigerZen/Unity3D-BlackJack-Dapp          C#
# 436   merdoyovski/Modified-Blackjack_Reach-Bounty-Hack       Shell
# 437                          DEEBAZZ890/Blackjack-game      Python
# 438                             cs361-W16/Blackjack-14        Java
# 439                              cs361-W16/Blackjack-8        Java
#
#                                        readme_contents
# 0    # Simplified Blackjack - Procedural\n\n## Lear...
# 1          # Rocket Academy Coding Basics: Blackjack\n
# 2    # RLCard: A Toolkit for Reinforcement Learning...
# 3    # Simplified Blackjack - Procedural\n\n## Lear...
# 4    # 21点游戏 - Cocos Creator 制造\n\n「21点游戏」是 Cocos C...
# ..                                                 ...
# 435  # Unity3D-BlackJack-Dapp\n\n教你使用Unity3D製作Dapp ...
# 436  # Reach Modified Blackjack DApp\n\nThis is a m...
# 437  # 21/Blackjack-game\n\nFrom a single deck of c...
# 438  [![Build Status](https://travis-ci.org/cs361-W...
# 439  # Blackjack-8\n\nTravis Status: [![Build Statu...
#
# [440 rows x 3 columns]

# %%
df2.language[df2.language == 'Jupyter Notebook'] = 'Python'

# %%
df2.language[(df2.language == 'Objective-C') 
             |(df2.language == 'C#')
            |(df2.language == 'C++') 
            |(df2.language == 'C')] = 'C_based'

# %%
df2.language[(df2.language == 'Swift') 
            | (df2.language == 'CSS') 
            | (df2.language == 'HTML')
            | (df2.language == 'TypeScript')
            | (df2.language == 'Lua')
            | (df2.language == 'Kotlin')
            | (df2.language == 'Vue')
            | (df2.language == 'Rust')
            | (df2.language == 'PHP')
            | (df2.language == 'Go')
            | (df2.language == 'Dart')
            | (df2.language == 'Roff')
            | (df2.language == 'Haskell')
            | (df2.language == 'Visual Basic')
            | (df2.language == 'Solidity')
            | (df2.language == 'Clojure')
            | (df2.language == 'Elixir')
            | (df2.language == 'Shell')] = 'Other'

# %%
df2.language.value_counts()
# Out:
# Ruby          216
# Java           52
# Other          43
# JavaScript     40
# Python         39
# C_based        28
# Name: language, dtype: int64

# %%
def get_links(csv_file):
    df = pd.read_csv(csv_file)
    return df

# %%
def get_languages(df):
    ndf = a.get_dataframe(df)
    return ndf

# %%
def clean_languages(df):
    df.language[df.language == 'Jupyter Notebook'] = 'Python'
    df.language[(df.language == 'Objective-C') 
             |(df.language == 'C#')
            |(df.language == 'C++') 
            |(df.language == 'C')] = 'C_based'
    df.language[(df.language == 'Swift') 
            | (df.language == 'CSS') 
            | (df.language == 'HTML')
            | (df.language == 'TypeScript')
            | (df.language == 'Lua')
            | (df.language == 'Kotlin')
            | (df.language == 'Vue')
            | (df.language == 'Rust')
            | (df.language == 'PHP')
            | (df.language == 'Go')
            | (df.language == 'Dart')
            | (df.language == 'Roff')
            | (df.language == 'Haskell')
            | (df.language == 'Visual Basic')
            | (df.language == 'Solidity')
            | (df.language == 'Clojure')
            | (df.language == 'Elixir')
            | (df.language == 'Shell')] = 'Other'
    return df

# %%
def drop_blanks(df):
    df = df[df.readme_contents != '']
    return df

# %%
data = df2

# %%
data = drop_blanks(data)
data = data['language'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 data = drop_blanks(data)
#       2 data = data['language'].str.strip()
#       3 data.value_counts()
#
# Input In [11], in drop_blanks(df)
#       1 def drop_blanks(df):
# ----> 2     df = df[df.readme_contents != '']
#       3     return df
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'readme_contents'

# %%
data = clean_languages(data)
data
# Out:
# /var/folders/hj/kp1r0j7515q27kbqjjy_89fm0000gn/T/ipykernel_4968/1720221538.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.language[df.language == 'Jupyter Notebook'] = 'Python'
# /var/folders/hj/kp1r0j7515q27kbqjjy_89fm0000gn/T/ipykernel_4968/1720221538.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.language[(df.language == 'Objective-C')
# /var/folders/hj/kp1r0j7515q27kbqjjy_89fm0000gn/T/ipykernel_4968/1720221538.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.language[(df.language == 'Swift')
#                                                   repo    language  \
# 0       learn-co-students/simple-blackjack-cli-prework        Ruby
# 1                       rocketacademy/basics-blackjack       Other
# 2                                     datamllab/rlcard      Python
# 3    learn-co-students/simple-blackjack-cli-001-pre...        Ruby
# 4          cocos-creator/tutorial-blackjack-deprecated  JavaScript
# ..                                                 ...         ...
# 435                    TigerZen/Unity3D-BlackJack-Dapp     C_based
# 436   merdoyovski/Modified-Blackjack_Reach-Bounty-Hack       Other
# 437                          DEEBAZZ890/Blackjack-game      Python
# 438                             cs361-W16/Blackjack-14        Java
# 439                              cs361-W16/Blackjack-8        Java
#
#                                        readme_contents
# 0    # Simplified Blackjack - Procedural\n\n## Lear...
# 1          # Rocket Academy Coding Basics: Blackjack\n
# 2    # RLCard: A Toolkit for Reinforcement Learning...
# 3    # Simplified Blackjack - Procedural\n\n## Lear...
# 4    # 21点游戏 - Cocos Creator 制造\n\n「21点游戏」是 Cocos C...
# ..                                                 ...
# 435  # Unity3D-BlackJack-Dapp\n\n教你使用Unity3D製作Dapp ...
# 436  # Reach Modified Blackjack DApp\n\nThis is a m...
# 437  # 21/Blackjack-game\n\nFrom a single deck of c...
# 438  [![Build Status](https://travis-ci.org/cs361-W...
# 439  # Blackjack-8\n\nTravis Status: [![Build Statu...
#
# [401 rows x 3 columns]

# %%
def remove_stopwords(input_string, extra_words=None, exclude_words=None):
    """
    This function takes an input and removes stopwords. You can add or remove words witht the extra_words or exclude_words args.
    """
    
    stopword_list = stopwords.words('english')
    if extra_words != None:
        stopword_list.extend(extra_words)
    if exclude_words != None:
        if type(extra_words) == str:
            stopword_list.remove(exclude_words)
        if type(extra_words) == list:
            for word in exclude_words:
                stopword_list.remove(word)
    words = input_string.split()
    filtered_words = [w for w in words if w not in stopword_list]
    string_without_stopwords = ' '.join(filtered_words)

    return string_without_stopwords

# %%
def basic_clean(input_string):
    """
    This function takes in a string and applies basic cleaning to it.
    """
    #Changes all characters to their lower case.
    input_string = input_string.lower()
    
    input_string = unicodedata.normalize('NFKD', input_string).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    #Removes special characters
    input_string = re.sub(r"[^a-z0-9\s]", '', input_string)
    input_string = re.sub(r'\n', ' ', input_string)
    input_string = re.sub(r'\s{2,}', ' ', input_string)
    return input_string

# %%
data['readme_contents'] = data['readme_contents'].apply(basic_clean)
data
# Out:
# /var/folders/hj/kp1r0j7515q27kbqjjy_89fm0000gn/T/ipykernel_4968/926009395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['readme_contents'] = data['readme_contents'].apply(basic_clean)
#                                                   repo    language  \
# 0       learn-co-students/simple-blackjack-cli-prework        Ruby
# 1                       rocketacademy/basics-blackjack       Other
# 2                                     datamllab/rlcard      Python
# 3    learn-co-students/simple-blackjack-cli-001-pre...        Ruby
# 4          cocos-creator/tutorial-blackjack-deprecated  JavaScript
# ..                                                 ...         ...
# 435                    TigerZen/Unity3D-BlackJack-Dapp     C_based
# 436   merdoyovski/Modified-Blackjack_Reach-Bounty-Hack       Other
# 437                          DEEBAZZ890/Blackjack-game      Python
# 438                             cs361-W16/Blackjack-14        Java
# 439                              cs361-W16/Blackjack-8        Java
#
#                                        readme_contents
# 0     simplified blackjack procedural learning goal...
# 1              rocket academy coding basics blackjack
# 2     rlcard a toolkit for reinforcement learning i...
# 3     simplified blackjack procedural learning goal...
# 4     21 cocos creator 21 cocos creator demo cocos ...
# ..                                                 ...
# 435   unity3dblackjackdapp unity3ddapp part2solidit...
# 436   reach modified blackjack dapp this is a modif...
# 437   21blackjackgame from a single deck of cards p...
# 438  build statushttpstravisciorgcs361w16blackjack1...
# 439   blackjack8 travis status build statushttpstra...
#
# [401 rows x 3 columns]

# %%
def tokenized(input_string):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    return tokenizer.tokenize(input_string, return_str=True)

# %%
data['readme_contents'] = data['readme_contents'].apply(tokenized)
data
# Out:
# /var/folders/hj/kp1r0j7515q27kbqjjy_89fm0000gn/T/ipykernel_4968/2381647320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['readme_contents'] = data['readme_contents'].apply(tokenized)
#                                                   repo    language  \
# 0       learn-co-students/simple-blackjack-cli-prework        Ruby
# 1                       rocketacademy/basics-blackjack       Other
# 2                                     datamllab/rlcard      Python
# 3    learn-co-students/simple-blackjack-cli-001-pre...        Ruby
# 4          cocos-creator/tutorial-blackjack-deprecated  JavaScript
# ..                                                 ...         ...
# 435                    TigerZen/Unity3D-BlackJack-Dapp     C_based
# 436   merdoyovski/Modified-Blackjack_Reach-Bounty-Hack       Other
# 437                          DEEBAZZ890/Blackjack-game      Python
# 438                             cs361-W16/Blackjack-14        Java
# 439                              cs361-W16/Blackjack-8        Java
#
#                                        readme_contents
# 0    simplified blackjack procedural learning goals...
# 1               rocket academy coding basics blackjack
# 2    rlcard a toolkit for reinforcement learning in...
# 3    simplified blackjack procedural learning goals...
# 4    21 cocos creator 21 cocos creator demo cocos c...
# ..                                                 ...
# 435  unity3dblackjackdapp unity3ddapp part2solidity...
# 436  reach modified blackjack dapp this is a modifi...
# 437  21blackjackgame from a single deck of cards pi...
# 438  build statushttpstravisciorgcs361w16blackjack1...
# 439  blackjack8 travis status build statushttpstrav...
#
# [401 rows x 3 columns]

# %%
def lemmatized(input_string):
    """
    Takes an input string and lemmatizes it.
    Please do not stem and lemmatize the same string.
    """
    #Creates the lemmatizer object
    wnl = nltk.stem.WordNetLemmatizer()
    
    #Makes lemmatade
    lemmas = [wnl.lemmatize(word) for word in input_string.split()]
    lemmatized_string = ' '.join(lemmas)
    
    return lemmatized_string

# %%
l = data['readme_contents'].apply(lemmatized)

# %%
def split(input_string):
    '''
    Creates and uses a snowball stemmer for readme data
    '''
    splitter = nltk.stem.SnowballStemmer('english')
    
    stem = [splitter.stem(word) for word in input_string.split()]
    split_string = ' '.join(stem)
    
    return split_string

# %%
s = data['readme_contents'].apply(split)

# %%
s[0]
# Out:
# 'simplifi blackjack procedur learn goal util condit logic and loop gain an introduct to the command line interfac background in blackjackhttpenwikipediaorgwikiblackjack the goal is to have a hand that is closer to 21 than the dealer hand without ever exceed a card total of 21 howev in this simplifi version of blackjack well cut out that compar with the dealer hand part and pretend that the goal of the game is to have a card total of or veri close to but never exceed 21 to start a player get dealt two card each of which has valu between 111 then the player is ask if they want to hit get anoth card dealt to them or stay if they hit they get dealt anoth card if the sum of their three card exceed 21 theyv lost if it doe not they can decid to hit or stay again forev if your think but now there no way to win then youd be right in this simpl simpl version of blackjack there is no way to win onc youv complet this lab feel free to make a second version where there is a way to win mayb even includ the real rule and compar the user hand to the dealer hand the command line interfac a brief note this is a brief introduct to command line app it okay if you dont understand everyth we discuss here were go to take a more indepth look in your next command line applic the cli or command line interfac is the interact between a user and their comput or a program via the command line youv alreadi becom comfort interact with the command line to navig file and connect with github and test your program in a command line applic the user will respond to a prompt that your program will output to the termin the user respons or input will be receiv by the applic and the applic will then carri out the program respons base on that input how doe put output text to the termin how do the put and print method actual output text to your consol they use the stdout global variabl provid to us by rubi you dont need to worri about global variabl right now for the purpos of understand how put and print work we just need to understand the follow your comput has a stdout file that communic with your oper system so put and print actual send output to the stdout variabl the stdout variabl send that inform to the stdout file on your comput which in turn communic with your oper system which in turn output that inform to the consol you can absolut employ put and print without understand everyth that was just describ but now you have a basic sens of what is happen under the hood of these method run our command line app we alreadi know that we can run or execut the code in a rubi file from the command line by type rubi file name in a command line app it is convent to creat a special file that has one respons execut the code that constitut our program you can think about this in term of the separ of concern principl the separ of concern principl is a program design principl for separ the respons and function into discret section for our command line app that mean that we have one file that defin the method we will use to play our blackjack game and a separ file that call those method then we will play our game by execut the that runner file via rubi runnerrb in the command line test our command line app you alreadi know that your blackjack command line app will reli on the user input to run in order to test our program use rspec we need a way for our test suit to fake the user input ie fake the implement of the put and get method this is call stub what is stub stub refer to the fake implement of a method in this case we will stub the put method to trick our test suit into think the stdout file has receiv the put method and to trick our test suit into recogn that the get method has been use first rubi expectstdoutto receiveputswithtyp h to hit or s to stay the abov line mean that the test suit is expect the execut of a certain method to use the put method to output type h to hit or s to stay second rubi expectselfto receivegetuserinputandreturn the abov line mean that the test s ...

# %%
data.value_counts().sum()
# Out:
# 380

# %%
len(data)
# Out:
# 401

# %%
data[data.isna() == True]
data.dropna()
# Out:
# 0            Ruby
# 1           Other
# 2          Python
# 3            Ruby
# 4      JavaScript
#           ...
# 435       C_based
# 436         Other
# 437        Python
# 438          Java
# 439          Java
# Name: language, Length: 380, dtype: object
